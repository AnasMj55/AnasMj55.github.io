# %%
import cv2
from ultralytics import YOLO
import math
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
cap = cv2.VideoCapture(0)

# %%
while True:
    ret, img = cap.read()
    results = model(img, stream=True)
# coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    
    cv2.imshow("Webcam", img)
    
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 persons, 71.5ms
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 60.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 1.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 57.5ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 1.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 59.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 55.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 54.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 59.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 57.3ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 57.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 1.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 cell phone, 56.5ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 58.5ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 1.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 56.5ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 55.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.0ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 54.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 52.5ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 53.5ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 53.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 52.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.32
# Class name --> bus
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.5ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bus, 53.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.27
# Class name --> bus
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.0ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 52.0ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.26
# Class name --> car
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 52.0ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.46
# Class name --> car
# Speed: 1.5ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 53.5ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.56
# Class name --> car
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.0ms
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 51.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.42
# Class name --> car
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 51.5ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.39
# Class name --> keyboard
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Confidence ---> 0.86
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 52.0ms
# Confidence ---> 0.35
# Class name --> remote
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 51.5ms
# Confidence ---> 0.45
# Class name --> keyboard
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 51.5ms
# Confidence ---> 0.32
# Class name --> keyboard
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dining table, 52.0ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.35
# Class name --> diningtable
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 keyboard, 56.0ms
# Confidence ---> 0.41
# Class name --> keyboard
# Speed: 0.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dining table, 51.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.55
# Class name --> diningtable
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dining table, 52.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.55
# Class name --> diningtable
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.0ms
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.0ms
# Confidence ---> 0.77
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 0.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.5ms
# Confidence ---> 0.94
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 keyboard, 51.0ms
# Confidence ---> 0.91
# Class name --> keyboard
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 52.0ms
# Confidence ---> 0.91
# Class name --> keyboard
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 52.5ms
# Confidence ---> 0.77
# Class name --> keyboard
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.5ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 0.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 55.5ms
# Confidence ---> 0.92
# Class name --> keyboard
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 52.5ms
# Confidence ---> 0.28
# Class name --> bed
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 52.0ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 book, 53.0ms
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 52.5ms
# Confidence ---> 0.92
# Class name --> keyboard
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 50.5ms
# Confidence ---> 0.91
# Class name --> keyboard
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 1 cell phone, 53.0ms
# Confidence ---> 0.8
# Class name --> keyboard
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 56.0ms
# Confidence ---> 0.9
# Class name --> keyboard
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 52.0ms
# Confidence ---> 0.87
# Class name --> keyboard
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 51.5ms
# Confidence ---> 0.87
# Class name --> keyboard
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.5ms
# Confidence ---> 0.85
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.0ms
# Confidence ---> 0.91
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Confidence ---> 0.89
# Class name --> keyboard
# Speed: 0.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.5ms
# Confidence ---> 0.85
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.1ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.0ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.5ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 55.5ms
# Confidence ---> 0.95
# Class name --> keyboard
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.0ms
# Confidence ---> 0.94
# Class name --> keyboard
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 keyboard, 54.0ms
# Confidence ---> 0.93
# Class name --> keyboard
# Confidence ---> 0.38
# Class name --> suitcase
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 55.0ms
# Confidence ---> 0.93
# Class name --> keyboard
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.0ms
# Confidence ---> 0.92
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 keyboard, 55.0ms
# Confidence ---> 0.93
# Class name --> keyboard
# Confidence ---> 0.49
# Class name --> suitcase
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Confidence ---> 0.92
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 52.5ms
# Confidence ---> 0.89
# Class name --> keyboard
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.5ms
# Confidence ---> 0.94
# Class name --> keyboard
# Speed: 1.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 53.0ms
# Confidence ---> 0.96
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.0ms
# Confidence ---> 0.91
# Class name --> keyboard
# Speed: 1.5ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 remote, 1 keyboard, 53.5ms
# Confidence ---> 0.75
# Class name --> keyboard
# Confidence ---> 0.53
# Class name --> remote
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 remote, 52.5ms
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> remote
# Speed: 0.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 remote, 1 keyboard, 53.0ms
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> keyboard
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 remote, 1 cell phone, 53.0ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> remote
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 53.5ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 53.5ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 56.0ms
# Confidence ---> 0.73
# Class name --> laptop
# Speed: 2.0ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 57.0ms
# Confidence ---> 0.84
# Class name --> laptop
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 61.0ms
# Confidence ---> 0.87
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 56.5ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 56.5ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.0ms
# Confidence ---> 0.48
# Class name --> laptop
# Speed: 1.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 63.0ms
# Confidence ---> 0.59
# Class name --> laptop
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 53.5ms
# Confidence ---> 0.43
# Class name --> laptop
# Speed: 2.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 55.0ms
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 54.5ms
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 0.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 54.5ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Confidence ---> 0.34
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 tvs, 1 laptop, 55.0ms
# Confidence ---> 0.72
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> tvmonitor
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 55.5ms
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 52.5ms
# Confidence ---> 0.97
# Class name --> bottle
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 53.0ms
# Confidence ---> 0.82
# Class name --> bottle
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.44
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> tvmonitor
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 55.0ms
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 tvs, 1 mouse, 54.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.69
# Class name --> mouse
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 tv, 1 laptop, 1 mouse, 54.5ms
# Confidence ---> 0.96
# Class name --> mouse
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.67
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> tvmonitor
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 1 keyboard, 55.5ms
# Confidence ---> 0.97
# Class name --> mouse
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> keyboard
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> remote
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 0.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 1 keyboard, 55.0ms
# Confidence ---> 0.97
# Class name --> mouse
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> keyboard
# Confidence ---> 0.55
# Class name --> remote
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 0.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 3 laptops, 1 mouse, 1 remote, 1 keyboard, 53.0ms
# Confidence ---> 0.95
# Class name --> mouse
# Confidence ---> 0.9
# Class name --> bottle
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.65
# Class name --> remote
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> keyboard
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 tv, 3 laptops, 1 mouse, 1 remote, 1 keyboard, 53.5ms
# Confidence ---> 0.95
# Class name --> mouse
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.52
# Class name --> keyboard
# Confidence ---> 0.46
# Class name --> remote
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 1 keyboard, 59.5ms
# Confidence ---> 0.96
# Class name --> mouse
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> remote
# Confidence ---> 0.52
# Class name --> keyboard
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 1.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 keyboard, 57.0ms
# Confidence ---> 0.98
# Class name --> mouse
# Confidence ---> 0.86
# Class name --> bottle
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> keyboard
# Confidence ---> 0.53
# Class name --> tvmonitor
# Confidence ---> 0.35
# Class name --> laptop
# Speed: 1.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 1 keyboard, 54.0ms
# Confidence ---> 0.98
# Class name --> mouse
# Confidence ---> 0.86
# Class name --> bottle
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.69
# Class name --> keyboard
# Confidence ---> 0.6
# Class name --> tvmonitor
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> remote
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 1 keyboard, 54.5ms
# Confidence ---> 0.95
# Class name --> mouse
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.5
# Class name --> keyboard
# Confidence ---> 0.49
# Class name --> remote
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 remote, 54.5ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.91
# Class name --> mouse
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> tvmonitor
# Confidence ---> 0.47
# Class name --> remote
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 2 laptops, 1 mouse, 1 cell phone, 54.5ms
# Confidence ---> 0.97
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 remote, 1 cell phone, 51.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> remote
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 54.5ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 54.5ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.94
# Class name --> mouse
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> keyboard
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 3 laptops, 1 mouse, 51.5ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 53.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.93
# Class name --> mouse
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> keyboard
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 60.0ms
# Confidence ---> 0.93
# Class name --> mouse
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> keyboard
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 0.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 53.5ms
# Confidence ---> 0.95
# Class name --> bottle
# Confidence ---> 0.87
# Class name --> mouse
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 53.5ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 54.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.82
# Class name --> mouse
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.59
# Class name --> tvmonitor
# Confidence ---> 0.53
# Class name --> laptop
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 53.0ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 56.5ms
# Confidence ---> 0.96
# Class name --> bottle
# Confidence ---> 0.92
# Class name --> mouse
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 2 mouses, 53.5ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.91
# Class name --> mouse
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.59
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> mouse
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 2 mouses, 1 keyboard, 53.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.78
# Class name --> mouse
# Confidence ---> 0.55
# Class name --> tvmonitor
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 55.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.39
# Class name --> keyboard
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 0.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 3 mouses, 1 keyboard, 1 cell phone, 52.5ms
# Confidence ---> 0.95
# Class name --> bottle
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> keyboard
# Confidence ---> 0.48
# Class name --> mouse
# Confidence ---> 0.42
# Class name --> mouse
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 55.5ms
# Confidence ---> 0.92
# Class name --> bottle
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.62
# Class name --> mouse
# Confidence ---> 0.51
# Class name --> cell phone
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> keyboard
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 53.5ms
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.43
# Class name --> mouse
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> keyboard
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 54.0ms
# Confidence ---> 0.95
# Class name --> bottle
# Confidence ---> 0.69
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 53.0ms
# Confidence ---> 0.88
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> mouse
# Confidence ---> 0.35
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 55.5ms
# Confidence ---> 0.87
# Class name --> bottle
# Confidence ---> 0.75
# Class name --> mouse
# Confidence ---> 0.44
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 0.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 book, 54.0ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 0.0ms preprocess, 54.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 mouse, 55.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 remote, 2 cell phones, 53.0ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> remote
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 remote, 1 cell phone, 52.5ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> remote
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 1.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 remote, 1 cell phone, 52.5ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> remote
# Confidence ---> 0.43
# Class name --> cell phone
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 remote, 1 cell phone, 53.0ms
# Confidence ---> 0.85
# Class name --> bottle
# Confidence ---> 0.67
# Class name --> remote
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 remote, 2 cell phones, 54.0ms
# Confidence ---> 0.82
# Class name --> bottle
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> remote
# Confidence ---> 0.45
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 1 laptop, 1 remote, 1 cell phone, 52.5ms
# Confidence ---> 0.88
# Class name --> bottle
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> remote
# Confidence ---> 0.34
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 remote, 1 cell phone, 52.5ms
# Confidence ---> 0.89
# Class name --> bottle
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> remote
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 remote, 52.5ms
# Confidence ---> 0.9
# Class name --> bottle
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> remote
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 remote, 1 cell phone, 56.0ms
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> remote
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 remote, 1 cell phone, 63.0ms
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> remote
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 cell phone, 51.5ms
# Confidence ---> 0.89
# Class name --> bottle
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 tv, 1 laptop, 1 cell phone, 54.5ms
# Confidence ---> 0.89
# Class name --> bottle
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 52.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 1.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 laptop, 52.5ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 laptop, 1 cell phone, 53.5ms
# Confidence ---> 0.89
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cell phone, 58.5ms
# Confidence ---> 0.88
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 53.0ms
# Confidence ---> 0.91
# Class name --> bottle
# Speed: 0.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 54.0ms
# Confidence ---> 0.85
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> suitcase
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 55.5ms
# Confidence ---> 0.91
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cell phone, 52.5ms
# Confidence ---> 0.83
# Class name --> bottle
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 knife, 53.0ms
# Confidence ---> 0.85
# Class name --> bottle
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.3
# Class name --> knife
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 knife, 1 remote, 55.0ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> knife
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 knife, 1 remote, 57.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> knife
# Confidence ---> 0.26
# Class name --> remote
# Speed: 0.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.5ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 laptop, 1 mouse, 53.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.37
# Class name --> mouse
# Confidence ---> 0.27
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.0ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# ...
#
# 0: 384x640 1 person, 55.5ms
# Confidence ---> 0.57
# Class name --> person
# Speed: 0.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 55.0ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.0ms
# Confidence ---> 0.57
# Class name --> person
# Speed: 0.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.5ms
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 0.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 0.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 0.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 0.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 0.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 55.5ms
# Confidence ---> 0.27
# Class name --> keyboard
# Speed: 1.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.0ms
# Confidence ---> 0.26
# Class name --> keyboard
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 0.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 mouse, 54.5ms
# Confidence ---> 0.32
# Class name --> mouse
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 mouse, 54.5ms
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 57.5ms
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 1.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 56.0ms
# Confidence ---> 0.41
# Class name --> keyboard
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 54.0ms
# Confidence ---> 0.57
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 53.5ms
# Confidence ---> 0.61
# Class name --> cell phone
# Speed: 0.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 56.5ms
# Confidence ---> 0.58
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 56.5ms
# Confidence ---> 0.58
# Class name --> cell phone
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 54.0ms
# Confidence ---> 0.62
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 57.0ms
# Confidence ---> 0.63
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 55.5ms
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.51
# Class name --> laptop
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 54.5ms
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> cell phone
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 57.5ms
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> cell phone
# Speed: 1.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
